# %% [markdown]
# ## 🌦️ Data Processing – Weather Observations (Hourly)
#
# The dataset `ObservedWather_Hourly.csv` contains hourly meteorological measurements
# from different stations between **2020–2024**.
#
# ### ⚠️ Challenges
# - The dataset had many technical/abbreviated names (e.g. `prec`, `hum`, `wd`),
#   making it unclear what each variable represented.
# - Multiple stations were included in the same file.
#
# ### 🛠️ Processing steps
# 1. **Loading**
# 2. **Manual renaming**
# 3. **Saving**
#
# ### ✅ Outcome
# We now have a **tidy hourly weather dataset** with clear feature names,
# ready to be merged with wind power and market data into the feature table `X`.

# %%
import pandas as pd

file_path = r"D:\WORK\4_STUDENT_DTU\OneDrive - Danmarks Tekniske Universitet\12_Semesters\5_13week_courses\46765_MachineLearning_EnergySystems\0.MachineLearning_EenrgySystems_Assignments\ProcessedData\Weather_Hourly_Clean.csv"

df_weather = pd.read_csv(file_path)

# Check basic structure
print("Shape:", df_weather.shape)
print("Columns:", df_weather.columns.tolist())
print(df_weather.head(10))
# Out:
# Shape: (42540, 17)
# Columns: ['ts', 'mean_IGR_Nex', 'mean_IGR_Hammer_Odde_Fyr', 'max_temp_Nex', 'max_temp_Hammer_Odde_Fyr', 'mean_temp_Nex', 'mean_temp_Hammer_Odde_Fyr', 'min_temp_Nex', 'min_temp_Hammer_Odde_Fyr', 'mean_hum_Nex', 'mean_hum_Hammer_Odde_Fyr', 'prec_Nex', 'prec_Hammer_ Odde_Fyr', 'mean_wind_speed_Nex', 'mean_wind_speed_Hammer_ Odde_Fyr', 'mean_wind_dir_Nex', 'mean_wind_dir_Hammer_ Odde_Fyr']
#               ts  mean_IGR_Nex  mean_IGR_Hammer_Odde_Fyr  max_temp_Nex  \
# 0  1/1/2020 0:00           0.0                       0.0           2.1
# 1  1/1/2020 1:00           0.0                       0.0           2.5
# 2  1/1/2020 2:00           0.0                       0.0           2.5
# 3  1/1/2020 3:00           0.0                       0.0           3.5
# 4  1/1/2020 4:00           0.0                       0.0           3.4
# 5  1/1/2020 5:00           0.0                       0.0           4.1
# 6  1/1/2020 6:00           0.0                       0.0           4.2
# ...
